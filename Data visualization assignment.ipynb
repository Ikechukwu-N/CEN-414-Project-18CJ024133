# %% [markdown]
# # NAME: NWAIGWE IKECHUKWU EMMANUEL NWAIGWE
# # MATRIC NUMBER: 18CJ024133
# # COURSE: CEN 414
# # TOPIC: PERCENTAGE OF BIRTHS DELIVERED BY CAESEREAN SECTION

# %%
country = np.array(["Benin","Burkina Faso","Burundi","Cameroon", "Congo", "Democratic Republic of Congo","Egypt","Equatoria Guinea","Eritrea","Ethiopia","Ghana","Guinea","Kenya","Lesotho", "Liberia","Madagascar","Malawi","Mali","Mauritius","Morocco", "Mozambique","Niger","Nigeria","Rwanda","Sao Tome and Principe","Senegal","Seychelles","Sierra Leone","Tanzania","Uganda","Zimbabwe"])
value = np.array([5.1, 1.5, 3.9, 3.8, 5.8, 4, 27.6, 6.6, 2.8, 1.5, 6.2, 2.4, 6.2, 6.7, 3.5, 1.5, 4.6, 1.6, 35.2, 4.4, 3.9, 0.7, 1.8, 7.5,5.3,5.1,13.8,1.2,3.2,5.2,4.2])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "green")
plt.title("Percent of births by caeserean section(2006)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics as stat
import math
plt.rcParams["figure.figsize"] = [16,8]
#country = np.array(["Algeria","Angola", "Burundi", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Cape verde", "Central African Republic", "Chad","Comoros", "Congo", "Democratic Republic of Congo", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Ivory coast", "Kenya", "Lesotho", "Liberia", "Libya", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger", "Nigeria", "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", "Swaziland", "Tanzania", "Togo", "Tunisia", "Uganda", "Zambia", "Zimbabwe"])

country = np.array(["Benin","Burkina Faso","Burundi","Cameroon", "Congo", "Democratic Republic of Congo","Egypt", "Eritrea", "Ethiopia", "Ghana", "Guinea", "Kenya", "Lesotho", "Liberia", "Madagascar", "Malawi", "Mali", "Mauritius", "Morocco", "Niger","Nigeria", "Rwanda","Sao Tome and Principe", "Senegal","Seychelles", "Sierra Leone","Tanzania", "Tunisia", "Uganda","Zimbabwe"])
value = np.array([5.4, 1.9, 4, 2, 3.2, 4, 19.9, 2.8, 1.5, 6.5, 1.7, 6.2, 9, 3.5, 1.5, 4.6, 1.6, 34.3, 3.8,1,1.8,7.2,5.3,5.1,19.2,1.5,3.2,20.5,5.3,4.5])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "red")
plt.title("Percent of births by caeserean section(2005)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
country = np.array(["Benin","Burkina Faso","Burundi","Cameroon","Central African Republic","Chad","Comoros","Congo","Democratic Republic of Congo","Djibouti","Egypt","Equatoria Guinea","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guinea","Guinea-Bissau","Kenya", "Lesotho","Liberia","Madagascar","Malawi", "Mali","Mauritius","Morocco","Mozambique","Namibia","Niger","Nigeria","Rwanda","Sao Tome and Principe","Senegal","Seychelles","Sierra Leone","South Sudan","Sudan","Swaziland","Tanzania","Uganda","Zimbabwe"])
value = np.array([4.4, 2.5, 3.8, 4.5, 4.5, 1.5, 9.6, 5.8, 7.2, 11, 22.6, 7.1, 2.2, 1.7, 9.4, 2.5, 6.9, 2.1, 2.3,6.8, 6.4, 3.5, 1.5, 4.7, 1.6, 40.4, 4.7, 3.5, 14.4, 0.7, 1.8, 7.5,5.3,5.1,19.3,1.2,0.6,6.6,12.3,3.2,5.2,4.2])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "black")
plt.title("Percent of births by caeserean section(2008)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
country = np.array(["Algeria","Angola","Benin","Burkina Faso","Burundi","Cameroon","Central African Republic","Chad","Comoros","Congo","Democratic Republic of Congo","Djibouti","Egypt","Equatoria Guinea","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guinea","Guinea-Bissau","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritius","Morocco","Mozambique","Namibia","Niger","Nigeria","Rwanda","Sao Tome and Principe","Senegal","Seychelles","Sierra Leone","South Sudan","Sudan","Swaziland","Tanzania","Uganda","Zimbabwe"])
value = np.array([16, 3.7, 6, 0.9, 6, 4.8, 3.5, 1.7, 6.6, 8.8, 5.2, 11, 51.8, 4.6, 3.8, 1.7, 8, 2.5, 11.4, 2.1, 2.3, 6.7, 2.5, 1.5, 4.7, 1.9, 43, 12.3, 4.9, 13.4, 3,2.2, 7.9,3.8,5.1,20.3,1.2,0.6,6.6,12.3,3.2,4.4,5.8])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "Gray")
plt.title("Percent of births by caeserean section(2010)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
country = np.array(["Benin","Burkina Faso","Burundi","Cameroon","Central African Republic","Chad","Comoros","Congo","Democratic Republic of Congo","Djibouti","Egypt","Equatoria Guinea","Eritrea","Ethiopia","Gabon", "Gambia","Ghana", "Guinea","Guinea-Bissau","Kenya","Lesotho", "Liberia","Madagascar","Malawi","Mali","Mauritius","Morocco","Mozambique","Namibia","Niger", "Nigeria","Rwanda","Sao Tome and Principe","Senegal","Seychelles","Sierra Leone","South Sudan","Sudan","Swaziland","Tanzania", "Uganda","Zimbabwe"])
value = np.array([6, 2.9, 4.8, 4.9, 5.5, 1.9, 11.6, 7.8, 9.2, 11, 51.8, 8.6, 3.8, 1.7, 12, 2.5, 11.4, 2.1, 2.3,8.7, 6.7, 2.5, 1.5, 4.7, 1.9, 41.6, 7.9, 4.9, 13.4, 3,2.2, 7.9,3.8,5.1,20.3,1.2,0.6,6.6,12.3,3.2,5.2,4.2])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "YELLOW")
plt.title("Percent of births by caeserean section(2009)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
country = np.array(["Algeria","Angola","Benin","Burkina Faso","Burundi","Cameroon","Chad","Comoros","Congo","Democratic Republic of Congo","Djibouti","Egypt","Equatoria Guinea", "Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guinea","Guinea-Bissau","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritius","Morocco","Mozambique","Namibia","Niger","Nigeria","Rwanda","Sao Tome and Principe", "Senegal","Seychelles","South Africa","Sierra Leone","Tanzania","Uganda","Zimbabwe"])
value = np.array([16, 3.7, 6, 3.7, 5, 3.8, 6, 3.5,5, 3.8, 1.4, 8.8, 5.2, 11, 51.8, 4.6, 3.8, 1.7, 8, 2.5, 11.4, 2.1, 2.3, 6.7, 2.5, 1.5, 4.7, 1.9, 43, 13, 3.8, 17.8,4.5,24.2,5.9,6.5,26.7,6.2,4.4,5.8])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "Brown")
plt.title("Percent of births by caeserean section(2011)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
country = np.array(["Algeria","Angola","Benin","Burkina Faso","Burundi","Cameroon","Chad","Comoros","Congo","Democratic Republic of Congo","Djibouti","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guinea","Guinea-Bissau","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritius","Morocco","Mozambique","Namibia","Niger","Nigeria","Rwanda","Sao Tome and Principe","Senegal","Seychelles","South Africa","Sierra Leone","Tanzania","Uganda","Zimbabwe"])
value = np.array([13, 5.7, 4.4, 1.7, 8, 2.4, 1.4, 9.6,5.8, 5.1, 1, 51.8, 11, 51.8, 2.1, 10, 1.7, 12.8, 2.5, 3.9, 9.7, 2.9, 6.7, 2.5, 1.5, 4.7, 1.9, 5.1, 2.7, 4.9,43.8,13.9,14.2,2,13,26.7,6.2,4.4,5.8])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "ORANGE")
plt.title("Percent of births by caeserean section(2012)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
country = np.array(["Benin","Burkina Faso","Burundi","Cameroon","Comoros","Congo","Democratic Republic of Congo","Djibouti","Egypt","Equatoria Guinea","Eritrea","Ethiopia","Gabon","Ghana", "Guinea","Kenya","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritius","Morocco","Mozambique","Niger","Nigeria","Rwanda","Sao Tome and Principe","Senegal","Seychelles", "Sierra Leone","Swaziland","Tanzania","Uganda","Zimbabwe"])
value = np.array([5, 2.2, 3.5, 3.5, 9.6, 5.8, 4, 11, 22.6, 7.1, 2.5, 1.2, 9.4, 6.9, 2.1, 6.8, 6.4, 3.5, 1.5, 4.7, 1.6, 39.1, 4.7, 3.5, 0.7, 1.8, 7.5,5.3,5.1,19.3,1.2,7.9,3.2,5.2,4.2])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "blue")
plt.title("Percent of births by caeserean section(2007)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
country = np.array(["Algeria","Angola","Benin","Burkina Faso","Burundi","Cameroon","Chad","Congo","Democratic Republic of Congo","Djibouti","Eritrea","Ethiopia","Gambia","Ghana","Guinea","Guinea-Bissau","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritius","Morocco","Mozambique","Namibia","Nigeria","Rwanda","Sao Tome and Principe","Senegal","Seychelles","South Africa","Sudan","Sierra Leone","Tanzania","Togo", "Uganda","Zimbabwe"])
value = np.array([8, 4.7, 5.3, 3.7, 4, 3.4, 2.4, 4.9, 6.1, 50.8, 2.1, 2, 12.8, 3.1, 3.9, 9.7, 2.9, 1.9, 5.1, 3.7, 4.9, 45.3, 14.2,14.4, 2.7, 13,5.6,4.4,24.2,2.9, 9,11.6,5.9,6.5,6.3,4.4,5.8])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "magenta")
plt.title("Percent of births by caeserean section(2013)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
country = np.array(["Angola","Benin","Burkina Faso","Burundi","Cameroon","Chad","Congo","Democratic Republic of Congo","Djibouti","Eritrea","Ethiopia","Ghana","Guinea","Guinea-Bissau","Liberia","Malawi","Mauritius","Rwanda","Sao Tome and Principe","Senegal","Seychelles","South Africa","Sudan","Sierra Leone","Tanzania","Togo","Uganda","Zimbabwe"])
value = np.array([4.7, 5.3, 6.7, 10, 5.4, 4.4, 8.9, 2.1, 25.8, 4.1, 12.8, 3.1, 3.9, 9.7,5.1,7.9, 49.2,13,5.6,4.4,14.9,24.2,11.6,5.9,6.5,6.3,4.4,5.8])
dfone = pd.DataFrame(value, index = country)
dfone.plot(kind="bar", width =0.4, color = "cyan")
plt.title("Percent of births by caeserean section(2014)")
plt.xlabel("Countries")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
plt.rcParams["figure.figsize"] = [16,8]
fig, ax = plt.subplots(1,1)
plt.rcParams["figure.figsize"] = [50,10]
plt.rcParams["figure.autolayout"] = True

data=[
    [mean1,median1,stdev1,var1],
    [mean2,median2,stdev2,var2],
    [mean3,median3,stdev3,var3],
    [mean4,median4,stdev4,var4],
    [mean5,median5,stdev5,var5],
    [mean6,median6,stdev6,var6],
    [mean7,median7,stdev7,var7],
    [mean8,median8,stdev8,var8],
    [mean9,median9,stdev9,var9],
    [mean10,median10,stdev10,var10]
]
column_labels = ["Mean", "Median", "Standard Deviation", "Variance"]
df = pd.DataFrame(data, columns=column_labels)
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df.values, colLabels = df.columns, rowLabels=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014], loc="center")
fig.suptitle('Measures of Dispersion', fontsize = 30, fontweight='bold')
plt.plot(years, mean)
plt.show()

# %%
plt.rcParams["figure.figsize"] = [16,8]
years = np.array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014])
mean = np.array([mean1, mean2, mean3, mean4, mean5, mean6, mean7, mean8, mean9, mean10])
plt.bar(years, mean)
plt.title("Mean")
plt.show()

# %%
plt.rcParams["figure.figsize"] = [16,8]
years = np.array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014])
stdev  = np.array([stdev1, stdev2 , stdev3, stdev4, stdev5, stdev6, stdev7, stdev8, stdev9, stdev10])
plt.bar(years, stdev)
plt.title("Standard deviation")
plt.show()

# %%
plt.rcParams["figure.figsize"] = [16,8]
years = np.array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014])
median  = np.array([median1, median2 , median3, median4, median5, median6, median7, median8, median9, median10])
plt.bar(years, median)
plt.title("Median")
plt.show()

# %%
plt.rcParams["figure.figsize"] = [16,8]
years = np.array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014])
var  = np.array([var1, var2 , var3, var4, var5, var6, var7, var8, var9, var10])
plt.bar(years, var)
plt.title("Variance")
plt.show()

# %%
plt.rcParams["figure.figsize"] = [16,8]
_range = np.array([34.3, 35.2, 39, 40, 52, 51.8, 52, 52, 51.8,51.8])
plt.plot(_range)
plt.ylabel("Range")
plt.xlabel("Years")
plt.title("Range")
# Out:
# Text(0.5, 1.0, 'Range')
